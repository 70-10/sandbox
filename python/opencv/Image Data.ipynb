# %%
import cv2
import numpy as np

# %%
img = cv2.imread("input.png")

# %%
height, width, ch = img.shape

# %%
size = width * height

# %%
print("width        = ", width)
print("height       = ", height)
print("channel     = ", ch)
print("size           = ", size)
print("data type = ", img.dtype)
print("R = ", img[0])
print("G = ", img[1])
print("B = ", img[2] )
# Out:
# width        =  200
# height       =  200
# channel     =  3
# size           =  40000
# data type =  uint8
# R =  [[ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
#  [ 36  28 237]
# ...
